# %%
"""
The performance of different approaches for solving SFCT. 
Each blue line shows the result of one replication of SAA, 
the blue line with the lowest expected makespan shows the 
performance of Augmented SAA, and the red line shows the 
performance of deterministic approach.
"""
