# %%
import numpy as np
import pandas as pd
import pickle
from gurobipy import *
from Data import Data
from Solver import Solver
from InventorySimulator import InventorySimulator
from Simulator import Simulator
from X_finder_None import X_finder_None

# %%
# find X for FCT | Objective = None

with open('dic_fct.pickle', 'rb') as handle:
    dic = pickle.load(handle)
    
for ii in range(1,49):
    for jj in range(1,11):
        print(ii , jj)
        X = X_finder_None(test_num=(ii,jj), dic=dic)
        file = './fct_all_None/' + str(ii) + '_' + str(jj) + '.x'
        np.savetxt(file, X.det_x, fmt='%d')

# %%
# read the optimals to print
df = pd.read_csv('./FCT_all.csv')
opt = {}
for r in range(len(df)):
    opt[(df.iloc[r]['i'], df.iloc[r]['j'])] = df.iloc[r]['lb']

# %%
# simulate FCT
dic = {}
for ii in range(1,49):
    for jj in range(1,11):
        data = Data((ii,jj))
        data.gen_scn(20, 2000)
        file = './fct_all_None/' + str(ii) + '_' + str(jj) + '.x'
        X = Simulator(model_type='sfct', file=file, data=data)
        if X.status:
            dic[(ii,jj)] = [X.obj]
            print('{}\t{}\t{}\t{}\t{}'.format(ii, jj, opt[ii,jj], X.obj, round(X.time, 4)))
        else:
            dic[(ii,jj)] = ['{}\t{}\t{}\t*************'.format(ii, jj, opt[ii,jj])]
# Out:
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 1	1	43.0	48.17859827478494	7.7383
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 1	2	47.0	52.359194083416625	9.8774
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 1	3	47.0	50.37952638375287	8.0492
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 1	4	62.0	67.20582787638311	6.7398
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 1	5	39.0	42.95533962260198	8.6643
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 1	6	48.0	52.708639748035715	8.3752
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 1	7	60.0	64.22366739367607	9.8299
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 1	8	53.0	58.82310921534151	7.839
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 1	9	49.0	53.62782606825883	9.043
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 1	10	45.0	49.75422842890693	7.5964
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 2	1	38.0	42.19272327853784	5.1574
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 2	2	51.0	54.84429206584608	5.9754
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 2	3	43.0	48.909819113621914	6.5802
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 2	4	43.0	48.595006480445555	7.3286
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 2	5	51.0	55.643150425355714	7.3138
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 2	6	47.0	51.45248694238785	7.8069
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 2	7	47.0	52.02671203137465	6.6578
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 2	8	54.0	59.44609643254707	8.6429
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 2	9	54.0	60.12995517930844	6.5716
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 2	10	43.0	48.07660354090998	7.3548
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 3	1	72.0	77.87226315071068	8.2318
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 3	2	40.0	44.99133510413359	5.3675
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 3	3	57.0	61.09943285343745	5.7416
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 3	4	98.0	103.67721459291973	10.8661
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 3	5	53.0	57.533849599927386	7.3197
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 3	6	54.0	58.875173113170206	6.9407
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 3	7	48.0	51.44856691591891	5.5799
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 3	8	54.0	57.72920843119728	6.3211
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 3	9	65.0	68.2610593286686	8.1655
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 3	10	59.0	63.15058072383255	8.0015
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 4	1	49.0	52.61640380175081	6.2384
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 4	2	60.0	62.905907707234974	7.4026
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 4	3	47.0	51.24434026752706	5.1603
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 4	4	57.0	59.89746709919814	6.8304
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 4	5	59.0	62.82926274299244	7.7169
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 4	6	45.0	49.542704062185614	6.9599
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 4	7	56.0	61.7117514118005	6.7701
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 4	8	55.0	60.07612431342895	7.455
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 4	9	38.0	43.048932013920414	4.8417
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 4	10	48.0	52.903059951603694	5.9551
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 5	1	53.0	58.021369904216314	6.8592
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 5	2	82.0	86.25979237851826	8.1288
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 5	3	76.0	80.85564632724513	8.7108
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 5	4	63.0	71.11936196166468	7.3005
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 5	5	76.0	82.52421391593	10.2702
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 5	6	64.0	68.8408105895988	7.6521
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 5	7	76.0	80.21168096917938	8.2055
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 5	8	67.0	72.51651521672547	8.8162
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 5	9	49.0	54.500037739023746	7.8123
# Changed value of parameter TimeLimit to 60.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# 5	10	70.0	75.67513871092278	8.7765

# %%
pd.DataFrame(dic).T.to_csv('./FCT_all_None.csv')
