# %%
from Solver import Solver
from InventorySimulator import InventorySimulator
import numpy as np
import pandas as pd
from Simulator import Simulator
from Data import Data
import os

# %%
"""
16-1   1.5, 1.00, 1.00
20-1   1.8, 0.25, 1.00
33-1   2.1, 0.25, 0.20
"""
# Out:
# '\n16-1   1.5, 1.00, 1.00\n20-1   1.8, 0.25, 1.00\n33-1   2.1, 0.25, 0.20\n'

# %%
tests = [(16,1), (20,1), (33,1)]

# %%
# find FCT X
for key in tests:
    X = Solver(key, 'fct')
    file = 'fct/' + str(key[0]) + '_' + str(key[1]) + '.x'
    np.savetxt(file, X.det_x, fmt='%d')

# %%
# simulate FCT
dic = {}
for k in tests:
    data = Data(k)
    data.gen_scn(20, 2000)
    file = './fct/' + str(k[0]) + '_' + str(k[1]) + '.x'
    X = Simulator(model_type='sfct', file=file, data=data)
    if X.status:
        dic[k] = [X.obj]
    else:
        dic[k] = ['FALSE']
pd.DataFrame(dic)
pd.DataFrame(dic).T.to_csv('./results/FCT_simulation.csv')

# %%
# find SFCT X
for key in tests:
    for it in range(20):
        X = Solver(key, 'sfct', iteration=it)
        file = 'sfct/' + str(key[0]) + '_' + str(key[1]) + '__' + str(it) + '.x'
        np.savetxt(file, X.det_x, fmt='%d')

# %%
# simulate SFCT
names = []
for root, dirs, files in os.walk("./sfct"):
    for filename in files:
        names.append(filename)
d = {}
for i, name in enumerate(names):
    if name[-1] == 'x':
        key = [int(s) for s in name.split('_')[:2]]
        try:
            d[key[0], key[1]].append(int(name.split('_')[-1].split('.')[0]))
        except:
            d[key[0], key[1]] = list([int(name.split('_')[-1].split('.')[0])])
for key in d:
    d[key] = sorted(d[key])

import pandas as pd
from Simulator import Simulator
from Data import Data

dic = {}
for k in d:
    data = Data(k)
    data.gen_scn(20, 2000)
    for i in d[k][:20]:
        file = './sfct/' + str(k[0]) + '_' + str(k[1]) + '__' + str(i) + '.x'
        X = Simulator(model_type='sfct', file=file, data=data)
        if X.status:
            dic[k[0], k[1], i] = [X.obj]
        else:
            raise Exception("status is False for {}".format(k))
pd.DataFrame(dic)
pd.DataFrame(dic).T.to_csv('./results/SFCT_simulation.csv')

# %%
# find ISFCT X
for gamma in [0.00005, 0.0001, 0.0002]:
    for key in tests:
        for it in range(20):
            X = Solver(key, 'isfct', iteration=it, gamma=gamma)
            file = 'isfct/' + str(key[0]) + '_' + str(key[1]) + '__' + str(it) +'___'+ str(gamma) + '.x'
            np.savetxt(file, X.det_x, fmt='%d')

# %%
dic = {}
dici = {}
for k in tests:
    data = Data(k)
    data.gen_scn(20, 2000)

# %%
data

# %%
sum(Data((16,1)).w)
# Out:
# 7.660177589976595

# %%
sum(Data((20,1)).w)
# Out:
# 6.198728426593579

# %%
sum(Data((33,1)).w)
# Out:
# 8.815094519542601

# %%
dici = {}
for gamma in [0.00005, 0.0001, 0.0002]:
    for k in tests:
        data = Data(k)
        data.gen_scn(20, 2000)
        a = pd.read_csv('./results/SFCT_simulation.csv')
        a.columns = ['i', 'j', 'r', 0]
        bound = min(list(a[(a['i']==k[0])&(a['j']==k[1])][0]))
        for it in range(20):
            for q in [1.01, 1.05]:
                try:
                    file = './isfct/' + str(k[0]) + '_' + str(k[1]) + '__' + str(it) +'___'+ str(gamma) + '.x'
                    X = InventorySimulator(file=file, data=data, bound=bound*q)
                    if X.status:
                        dici[k, q, it, gamma] = [X.obj]
                    else:
                        dici[k, q, it, gamma] = ['FALSE']
                except:
                    print('********************* {} - {}  --  {}'.format(k, it, gamma))
dici
# Out:
# Changed value of parameter TimeLimit to 120.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# Changed value of parameter TimeLimit to 120.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# Changed value of parameter TimeLimit to 120.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# Changed value of parameter TimeLimit to 120.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# Changed value of parameter TimeLimit to 120.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# Changed value of parameter TimeLimit to 120.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# Changed value of parameter TimeLimit to 120.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# Changed value of parameter TimeLimit to 120.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# Changed value of parameter TimeLimit to 120.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# ...

# %%
dic = {}
for k in tests:
    data = Data(k)
    data.gen_scn(20, 2000)
    a = pd.read_csv('./results/SFCT_simulation.csv')
    a.columns = ['i', 'j', 'r', 0]
    bound = min(list(a[(a['i']==k[0])&(a['j']==k[1])][0]))
    for it in range(20):
        for q in [1.01, 1.05]:
            try:
                file = './sfct/' + str(k[0]) + '_' + str(k[1]) + '__' + str(it) + '.x'
                X = InventorySimulator(file=file, data=data, bound=bound*q)
                if X.status:
                    dic[k, q, it] = [X.obj]
                else:
                    dic[k, q, it] = ['FALSE']
            except:
                print('********************* {} - {}'.format(k, it))
dic
# Out:
# Changed value of parameter TimeLimit to 120.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# Changed value of parameter TimeLimit to 120.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# Changed value of parameter TimeLimit to 120.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# Changed value of parameter TimeLimit to 120.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# Changed value of parameter TimeLimit to 120.0
#    Prev: 1e+100  Min: 0.0  Max: 1e+100  Default: 1e+100
# ******** problem (16, 1) is not solved optimally.
# Changed value of parameter TimeLimit to 120.0
 ((33, 1), 1.01, 18): [17.370887645160046],
 ((33, 1), 1.05, 18): [5.479898204873109],
 ((33, 1), 1.01, 19): [18.57623459314533],
 ((33, 1), 1.05, 19): [5.651491047865726]}

# %%
dic
# Out:
# {((16, 1), 1.01, 0): [6.399169148116153],
#  ((16, 1), 1.05, 0): [1.757328826212861],
#  ((16, 1), 1.01, 1): [4.4252396675219465],
#  ((16, 1), 1.05, 1): [1.2481893441332454],
#  ((16, 1), 1.01, 2): ['FALSE'],
#  ((16, 1), 1.05, 2): [1.9167425399394267],
#  ((16, 1), 1.01, 3): [5.647370757633124],
#  ((16, 1), 1.05, 3): [1.6063905265384584],
#  ((16, 1), 1.01, 4): [9.765411083201075],
#  ((16, 1), 1.05, 4): [1.8117600060707213],
#  ((16, 1), 1.01, 5): [6.593473144479993],
#  ((16, 1), 1.05, 5): [1.7308566901592402],
#  ((16, 1), 1.01, 6): [5.7847220109740025],
#  ((16, 1), 1.05, 6): [1.782491435338505],
#  ((16, 1), 1.01, 7): ['FALSE'],
#  ((16, 1), 1.05, 7): [2.42281823334683],
#  ((16, 1), 1.01, 8): [7.308209642687593],
#  ((16, 1), 1.05, 8): [1.8660370529129633],
#  ((16, 1), 1.01, 9): [10.614164912910985],
#  ((16, 1), 1.05, 9): [1.7553341658047037],
#  ((16, 1), 1.01, 10): [11.129891899708177],
#  ((16, 1), 1.05, 10): [2.0212386875417776],
# ...

# %%
d = {}
K = list(dic.keys())
for kk in K:
    d[kk[0], kk[1]] = 100
for k in tests:
    for kk in K:
        if k == kk[0]:
            if dic[kk][0] != 'FALSE':
                if d[k,kk[1]] > dic[kk][0]:
                    d[k,kk[1]] = dic[kk][0]

# %%
d
# Out:
# {((16, 1), 1.01): 4.4252396675219465,
#  ((16, 1), 1.05): 1.2481893441332454,
#  ((20, 1), 1.01): 4.880018154551138,
#  ((20, 1), 1.05): 1.4221575702749476,
#  ((33, 1), 1.01): 17.25352398519602,
#  ((33, 1), 1.05): 5.451532366817531}

# %%
d = {}
K = list(dici.keys())
for kk in K:
    d[kk[0], kk[1]] = 100
for k in tests:
    for kk in K:
        if k == kk[0]:
            if dici[kk][0] != 'FALSE':
                if d[k,kk[1]] > dici[kk][0]:
                    d[k,kk[1]] = dici[kk][0]

# %%
d
# Out:
# {((16, 1), 1.01): 3.9056113013498495,
#  ((16, 1), 1.05): 1.1241220270333931,
#  ((20, 1), 1.01): 4.613559227951782,
#  ((20, 1), 1.05): 1.375430320887567,
#  ((33, 1), 1.01): 17.240110853252844,
#  ((33, 1), 1.05): 5.451431774881151}

# %%
tests[0] == K[0][0]
# Out:
# True

# %%
dic[K[0]][0]
# Out:
# 6.399169148116153

# %%
d
# Out:
# {((16, 1), 1.01): 4.4252396675219465,
#  ((16, 1), 1.05): 1.2481893441332454,
#  ((20, 1), 1.01): 100,
#  ((20, 1), 1.05): 100,
#  ((33, 1), 1.01): 100,
#  ((33, 1), 1.05): 100}

# %%
dic
# Out:
# {((16, 1), 1.01, 0): [6.399169148116153],
#  ((16, 1), 1.05, 0): [1.757328826212861],
#  ((16, 1), 1.01, 1): [4.4252396675219465],
#  ((16, 1), 1.05, 1): [1.2481893441332454],
#  ((16, 1), 1.01, 2): ['FALSE'],
#  ((16, 1), 1.05, 2): [1.9167425399394267],
#  ((16, 1), 1.01, 3): [5.647370757633124],
#  ((16, 1), 1.05, 3): [1.6063905265384584],
#  ((16, 1), 1.01, 4): [9.765411083201075],
#  ((16, 1), 1.05, 4): [1.8117600060707213],
#  ((16, 1), 1.01, 5): [6.593473144479993],
#  ((16, 1), 1.05, 5): [1.7308566901592402],
#  ((16, 1), 1.01, 6): [5.7847220109740025],
#  ((16, 1), 1.05, 6): [1.782491435338505],
#  ((16, 1), 1.01, 7): ['FALSE'],
#  ((16, 1), 1.05, 7): [2.42281823334683],
#  ((16, 1), 1.01, 8): [7.308209642687593],
#  ((16, 1), 1.05, 8): [1.8660370529129633],
#  ((16, 1), 1.01, 9): [10.614164912910985],
#  ((16, 1), 1.05, 9): [1.7553341658047037],
#  ((16, 1), 1.01, 10): [11.129891899708177],
#  ((16, 1), 1.05, 10): [2.0212386875417776],
# ...

# %%
d
# Out:
# {((16, 1), 1.01): 3.9056113013498495,
#  ((16, 1), 1.05): 1.1241220270333931,
#  ((20, 1), 1.01): 4.613559227951782,
#  ((20, 1), 1.05): 1.375430320887567,
#  ((33, 1), 1.01): 17.240110853252844,
#  ((33, 1), 1.05): 5.451431774881151}

# %%
for k in dici:
    if (k[1] == 1.01) & (k[0] == (33,1)):
        print(k, dici[k])
# Out:
# ((33, 1), 1.01, 0, 5e-05) [17.277514732556483]
# ((33, 1), 1.01, 1, 5e-05) [17.371650880386774]
# ((33, 1), 1.01, 2, 5e-05) [17.38148486319588]
# ((33, 1), 1.01, 3, 5e-05) [17.357465270653442]
# ((33, 1), 1.01, 4, 5e-05) [17.254528950730823]
# ((33, 1), 1.01, 5, 5e-05) [17.277514732556483]
# ((33, 1), 1.01, 6, 5e-05) [17.395219356973982]
# ((33, 1), 1.01, 7, 5e-05) [17.371141477889097]
# ((33, 1), 1.01, 8, 5e-05) [17.254528950730823]
# ((33, 1), 1.01, 9, 5e-05) [17.385321643761266]
# ((33, 1), 1.01, 10, 5e-05) [17.361115852624728]
# ((33, 1), 1.01, 11, 5e-05) [17.384557230080723]
# ((33, 1), 1.01, 12, 5e-05) [17.400034205305026]
# ((33, 1), 1.01, 13, 5e-05) [17.240110853252844]
# ((33, 1), 1.01, 14, 5e-05) [17.25352398519602]
# ((33, 1), 1.01, 15, 5e-05) [17.277514732556483]
# ((33, 1), 1.01, 16, 5e-05) [17.25352398519602]
# ((33, 1), 1.01, 17, 5e-05) [17.25352398519602]
# ((33, 1), 1.01, 18, 5e-05) [17.3574431492218]
# ((33, 1), 1.01, 19, 5e-05) [17.38148486319588]
# ...
